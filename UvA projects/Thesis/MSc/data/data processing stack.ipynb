# %%
import pandas as pd
import numpy as np

# %%
# df = pd.read_excel(r"/Users/jinhyun/Documents/GitHub/Python/UvA projects/Thesis/MSc/data/Process/Process 1 (transpose)/Data_Extract_From_Education_processed.xlsx", sheet_name="Sheet1", header=[0,3])
df = pd.read_excel(r"/Users/jinhyun/Documents/GitHub/Python/UvA projects/Thesis/MSc/data/Process/Process 1 (transpose)/Data_Extract_From_Industry_processed.xlsx", sheet_name="Sheet1", header=[0,3])
# df = pd.read_excel(r"/Users/jinhyun/Documents/GitHub/Python/UvA projects/Thesis/MSc/data/Process/Process 1 (transpose)/Data_Extract_From_inflation_processed.xlsx", sheet_name="Sheet1", header=[0,3])
# df = pd.read_excel(r"/Users/jinhyun/Documents/GitHub/Python/UvA projects/Thesis/MSc/data/Process/Process 1 (transpose)/Data_Extract_From_Investment_processed.xlsx", sheet_name="Sheet1", header=[0,3])
# df = pd.read_excel(r"/Users/jinhyun/Documents/GitHub/Python/UvA projects/Thesis/MSc/data/Process/Process 1 (transpose)/Data_Extract_From_trade openess_processed.xlsx", sheet_name="Sheet1", header=[0,3])

# %%
df
# Out:
#      Country Name Afghanistan                                               \
#       Series Code SP.ADO.TFRT NV.AGR.TOTL.ZS ER.H2O.FWTL.ZS SH.STA.BRTC.ZS
# 0   1960 [YR1960]     145.245             ..             ..             ..
# 1   1961 [YR1961]     145.245             ..             ..             ..
# 2   1962 [YR1962]     145.245             ..             ..             ..
# 3   1963 [YR1963]     145.245             ..             ..             ..
# 4   1964 [YR1964]     145.245             ..             ..             ..
# ..            ...         ...            ...            ...            ...
# 57  2017 [YR2017]      68.957      26.420199      43.015907           53.4
# 58  2018 [YR2018]      65.141      22.042897             ..           58.8
# 59  2019 [YR2019]      61.325      25.773971             ..             ..
# 60  2020 [YR2020]      57.509        26.8206             ..             ..
# ...

# %%
years = [y[:4] for y in list(df['Country Name']['Series Code'])]
print(years)
# Out:
# ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']

# %%
df.columns
# Out:
# MultiIndex([('Country Name',       'Series Code'),
#             ( 'Afghanistan',       'SP.ADO.TFRT'),
#             ( 'Afghanistan',    'NV.AGR.TOTL.ZS'),
#             ( 'Afghanistan',    'ER.H2O.FWTL.ZS'),
#             ( 'Afghanistan',    'SH.STA.BRTC.ZS'),
#             ( 'Afghanistan',    'EN.ATM.CO2E.PC'),
#             ( 'Afghanistan',    'SP.DYN.CONU.ZS'),
#             ( 'Afghanistan', 'FS.AST.DOMS.GD.ZS'),
#             ( 'Afghanistan', 'EG.USE.ELEC.KH.PC'),
#             ( 'Afghanistan', 'EG.USE.PCAP.KG.OE'),
#             ...
#             (       'World',       'SE.PRM.ENRR'),
#             (       'World', 'SE.ENR.PRSC.FM.ZS'),
#             (       'World',       'SE.SEC.ENRR'),
#             (       'World',       'IQ.SCI.OVRL'),
#             (       'World',    'AG.SRF.TOTL.K2'),
#             (       'World', 'GC.TAX.TOTL.GD.ZS'),
#             (       'World',    'ER.PTD.TOTL.ZS'),
#             (       'World',       'IC.REG.DURS'),
# ...

# %%
countries = sorted(list(set([col[0] for col in df.columns[1:]])))
countries
# Out:
# ['Afghanistan',
#  'Africa Eastern and Southern',
#  'Africa Western and Central',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Arab World',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Caribbean small states',
#  'Cayman Islands',
#  'Central African Republic',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
# ...

# %%
year_start = 1987

for country in countries:
    df[country, 'Country'] = [country]*df.shape[0]
    df[country, 'Year'] = years 

del df['Country Name']

df
# Out:
# /var/folders/b7/2drx61nd6j9dlpqcgh7p1gym0000gn/T/ipykernel_2650/339425644.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[country, 'Year'] = years
# /var/folders/b7/2drx61nd6j9dlpqcgh7p1gym0000gn/T/ipykernel_2650/339425644.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[country, 'Country'] = [country]*df.shape[0]
#    Afghanistan                                                              \
#    SP.ADO.TFRT NV.AGR.TOTL.ZS ER.H2O.FWTL.ZS SH.STA.BRTC.ZS EN.ATM.CO2E.PC
# ...

# %%
# df_edu['Afghanistan']['Country'], df_edu['Afghanistan']['Year'] = ['Afghanistan']*df_edu.shape[0], list(df_edu['Country Name']['Series Code'])

# %%
df2 = pd.concat([df[country] for country in countries])
df2.head(50)
# Out:
#    SP.ADO.TFRT NV.AGR.TOTL.ZS ER.H2O.FWTL.ZS SH.STA.BRTC.ZS EN.ATM.CO2E.PC  \
# 0      145.245             ..             ..             ..             ..
# 1      145.245             ..             ..             ..             ..
# 2      145.245             ..             ..             ..             ..
# 3      145.245             ..             ..             ..             ..
# 4      145.245             ..             ..             ..             ..
# 5      145.245             ..             ..             ..             ..
# 6      145.245             ..             ..             ..             ..
# 7      145.245             ..             ..             ..             ..
# 8      145.245             ..             ..             ..             ..
# 9      145.245             ..             ..             ..             ..
# 10     145.245             ..             ..             ..             ..
# ...

# %%
# df2.to_excel(r'/Users/jinhyun/Documents/GitHub/Python/UvA projects/Thesis/MSc/data/Process/Process 2 (stack)/edu_stack.xlsx', index = False)
df2.to_excel(r'/Users/jinhyun/Documents/GitHub/Python/UvA projects/Thesis/MSc/data/Process/Process 2 (stack)/Industry_stack.xlsx', index = False)
# df2.to_excel(r'/Users/jinhyun/Documents/GitHub/Python/UvA projects/Thesis/MSc/data/Process/Process 2 (stack)/Inflation_stack.xlsx', index = False)
# df2.to_excel(r'/Users/jinhyun/Documents/GitHub/Python/UvA projects/Thesis/MSc/data/Process/Process 2 (stack)/Investment_stack.xlsx', index = False)
# df2.to_excel(r'/Users/jinhyun/Documents/GitHub/Python/UvA projects/Thesis/MSc/data/Process/Process 2 (stack)/Trade openess.xlsx', index = False)
