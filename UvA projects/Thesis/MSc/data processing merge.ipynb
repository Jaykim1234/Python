# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"/Users/jinhyun/Documents/GitHub/Python/UvA projects/Thesis/MSc/data/Process/Process 3 (merge)/merged original_processing_4.xlsx", sheet_name="Sheet1", header=[1])
# df_inf  = pd.read_excel(r"/Users/jinhyun/Documents/GitHub/Python/UvA projects/Thesis/MSc/data/Process/Process 2 (stack)/Inflation_stack.xlsx", sheet_name="Sheet1")
# df_inv  = pd.read_excel(r"/Users/jinhyun/Documents/GitHub/Python/UvA projects/Thesis/MSc/data/Process/Process 2 (stack)/Investment_stack.xlsx", sheet_name="Sheet1")
# df_to   = pd.read_excel(r"/Users/jinhyun/Documents/GitHub/Python/UvA projects/Thesis/MSc/data/Process/Process 2 (stack)/Trade openess.xlsx", sheet_name="Sheet1")

# %%
df
# Out:
#        Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                             140.120535
# 1                                             140.594564
# 2                                             141.128109
# 3                                             141.323440
# 4                                             141.508160
# ...                                                  ...
# 13388                                          86.135000
# 13389                                          83.248600
# 13390                                          80.362200
# 13391                                          77.475800
# 13392                                                NaN
#
#        Agriculture, forestry, and fishing, value added (% of GDP)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# ...

# %%
len(list(df.columns)[:-2])
# Out:
# 21

# %%
len(list(df.columns))
# Out:
# 23

# %%
# df2 = df[list(df.columns)[:-2]].isnull().groupby([df['Country']]).transform('sum').astype(int)

# %%
# df2 = df.isnull().groupby([df['Country']]).transform('sum')

# %%
df2 =  df.isnull().groupby([df['Country']]).sum()

# %%
df2
# Out:
#                              Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# Country
# Africa Eastern and Southern                                                  1
# Africa Western and Central                                                   1
# Albania                                                                      1
# Algeria                                                                      1
# Angola                                                                       1
# ...                                                                        ...
# West Bank and Gaza                                                           1
# World                                                                        1
# Yemen, Rep.                                                                  1
# Zambia                                                                       1
# Zimbabwe                                                                     1
#
# ...

# %%
df2.to_excel("nan count.xlsx")

# %%
df_del = pd.read_excel(r"/Users/jinhyun/Documents/GitHub/Python/UvA projects/Thesis/MSc/deleting country list.xlsx", sheet_name="Sheet1")

# %%
# df_del.to_excel('')

# %%
country_check= list(df_del['Country_delete'])

# %%
df['Check'] = df['Country'].apply(lambda x:  x in country_check)

# %%
df.head(20)
# Out:
#     Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                          140.120535
# 1                                          140.594564
# 2                                          141.128109
# 3                                          141.323440
# 4                                          141.508160
# 5                                          141.668896
# 6                                          141.879704
# 7                                          141.983225
# 8                                          142.020168
# 9                                          142.010506
# 10                                         142.033458
# 11                                         142.279778
# 12                                         142.629356
# 13                                         142.469778
# 14                                         142.290486
# 15                                         142.053901
# ...

# %%
df3 = df.loc[df['Check'] == False]

# %%
df3.head(30)
# Out:
#      Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 186                                           123.8892
# 187                                           124.7566
# 188                                           125.6240
# 189                                           123.5016
# 190                                           121.3792
# 191                                           119.2568
# 192                                           117.1344
# 193                                           115.0120
# 194                                           112.6814
# 195                                           110.3508
# 196                                           108.0202
# 197                                           105.6896
# 198                                           103.3590
# 199                                           101.6092
# 200                                            99.8594
# 201                                            98.1096
# ...

# %%
df3.to_excel('data_colleted_raw.xlsx')

# %%
df3.fillna( method ='bfill', inplace = True)
df3.head(30)
# Out:
# /Users/jinhyun/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#      Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 186                                           123.8892
# 187                                           124.7566
# 188                                           125.6240
# 189                                           123.5016
# 190                                           121.3792
# 191                                           119.2568
# 192                                           117.1344
# 193                                           115.0120
# 194                                           112.6814
# 195                                           110.3508
# ...

# %%
df3.to_excel('data_raw_miss_bfill.xlsx')

# %%
df3.fillna( method ='ffill', inplace = True)
df3.head(30)
# Out:
# /Users/jinhyun/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#      Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 186                                           123.8892
# 187                                           124.7566
# 188                                           125.6240
# 189                                           123.5016
# 190                                           121.3792
# 191                                           119.2568
# 192                                           117.1344
# 193                                           115.0120
# 194                                           112.6814
# 195                                           110.3508
# ...

# %%
df3.to_excel('data_raw_miss_b_ffill.xlsx')

# %%
df3.isnull().sum()
# Out:
# Adolescent fertility rate (births per 1,000 women ages 15-19)    0
# Agriculture, forestry, and fishing, value added (% of GDP)       0
# Exports of goods and services (% of GDP)                         0
# Fertility rate, total (births per woman)                         0
# Foreign direct investment, net inflows (BoP, current US$)        0
# GDP (current US$)                                                0
# GDP growth (annual %)                                            0
# Gross capital formation (% of GDP)                               0
# Imports of goods and services (% of GDP)                         0
# Industry (including construction), value added (% of GDP)        0
# Inflation, GDP deflator (annual %)                               0
# Life expectancy at birth, total (years)                          0
# Merchandise trade (% of GDP)                                     0
# Mobile cellular subscriptions (per 100 people)                   0
# ...
