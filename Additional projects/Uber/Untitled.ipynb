# %%
import pandas as pd

df = pd.read_excel (r'./\uber_deliveryServiceDataset.xlsx')
print (df)
# Out:
#          Date  Hour  Requests  Completes  Supply Hours  Time On Trip  pETA  \
# 0  2013-09-01    11        79         55         42.63         20.43  5.51
# 1         NaT    12        73         41         36.43         15.53  5.48
# 2         NaT    13        54         50         23.02         17.76  5.07
# 3  2013-09-02    11       193        170         64.20         31.47  5.31
# 4         NaT    12       258        210         80.28         38.68  4.94
# ..        ...   ...       ...        ...           ...           ...   ...
# 85        NaT    12       378        306         99.07         52.02  5.75
# 86        NaT    13       321        149         76.90         30.55  5.86
# 87 2013-09-30    11       180        151         68.33         24.87  5.21
# 88        NaT    12       307        247         78.25         45.78  5.75
# 89        NaT    13       215        275         56.83         29.13  5.35
#
#     aETA  Delivered Products  Total Products Available
# ...

# %%
df.iloc[3,:]
# Out:
# Date                        2013-09-02 00:00:00
# Hour                                         11
# Requests                                    193
# Completes                                   170
# Supply Hours                               64.2
# Time On Trip                              31.47
# pETA                                       5.31
# aETA                                       6.55
# Delivered Products                          288
# Total Products Available                    414
# Name: 3, dtype: object

# %%
df_ratio = df['Requests']/df['Completes']
df['ratio'] = df_ratio

# %%
df_11h = df[df['Hour'] == 11]
df_12h = df[df['Hour'] == 12]
df_13h = df[df['Hour'] == 13]

# %%
df_13h['ratio'].mean()
# Out:
# 2.4115468507283326

# %%
df[df['Hour'] == 11].mean()
# Out:
# <ipython-input-19-7677dff0e33e>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df[df['Hour'] == 11].mean()
# Hour                         11.000000
# Requests                    200.266667
# Completes                   151.666667
# Supply Hours                 55.333667
# Time On Trip                 25.617000
# pETA                          5.397333
# aETA                          6.611000
# Delivered Products          289.233333
# Total Products Available    407.166667
# ratio                         1.479300
# dtype: float64

# %%
df[df['Hour'] == 12].mean()
# Out:
# <ipython-input-20-fca385852124>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df[df['Hour'] == 12].mean()
# Hour                         12.000000
# Requests                    284.333333
# Completes                   195.000000
# Supply Hours                 60.601000
# Time On Trip                 37.176000
# pETA                          5.860000
# aETA                          7.253333
# Delivered Products           60.366667
# Total Products Available    123.766667
# ratio                         1.682015
# dtype: float64

# %%
df[df['Hour'] == 13].mean()
# Out:
# <ipython-input-21-da1565de5e6d>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df[df['Hour'] == 13].mean()
# Hour                         13.000000
# Requests                    215.966667
# Completes                   102.833333
# Supply Hours                 42.486667
# Time On Trip                 24.361000
# pETA                          6.018333
# aETA                          7.732667
# Delivered Products           12.200000
# Total Products Available     19.000000
# ratio                         2.411547
# dtype: float64

# %%
df2 = df.groupby('Date').sum()
df2.head()
# Out:
#             Hour  Requests  Completes  Supply Hours  Time On Trip  pETA  aETA  \
# Date
# 2013-09-01    11        79         55         42.63         20.43  5.51  7.19
# 2013-09-02    11       193        170         64.20         31.47  5.31  6.55
# 2013-09-03    11       124         34         30.67         19.65  6.70  8.19
# 2013-09-04    11        98         43         29.17         16.55  6.99  8.32
# 2013-09-05    11       184        167         58.32         25.03  4.84  5.65
#
#             Delivered Products  Total Products Available     ratio
# Date
# 2013-09-01                 103                       159  1.436364
# 2013-09-02                 288                       414  1.135294
# 2013-09-03                  67                       129  3.647059
# 2013-09-04                  44                       100  2.279070
# 2013-09-05                 312                       359  1.101796

# %%
df2_com_ratio = df2['Completes']/df2['Requests']

# %%
df2_com_ratio
# Out:
# Date
# 2013-09-01    0.696203
# 2013-09-02    0.880829
# 2013-09-03    0.274194
# 2013-09-04    0.438776
# 2013-09-05    0.907609
# 2013-09-06    0.883041
# 2013-09-07    0.871345
# 2013-09-08    0.807882
# 2013-09-09    0.727700
# 2013-09-10    0.897959
# 2013-09-11    0.248366
# 2013-09-12    0.837838
# 2013-09-13    0.888889
# 2013-09-14    0.788644
# 2013-09-15    0.837838
# 2013-09-16    0.860759
# 2013-09-17    0.840909
# 2013-09-18    0.658824
# 2013-09-19    0.609890
# 2013-09-20    0.746575
# 2013-09-21    0.810976
# 2013-09-22    0.879085
# 2013-09-23    0.775424
# 2013-09-24    0.622642
# 2013-09-25    0.902439
# 2013-09-26    0.521739
# 2013-09-27    0.819672
# 2013-09-28    0.863636
# 2013-09-29    0.794702
# 2013-09-30    0.838889
# dtype: float64

# %%
df2_com_ratio.max()
# Out:
# 0.907608695652174

# %%
df2.columns
# Out:
# Index(['Hour', 'Requests', 'Completes', 'Supply Hours', 'Time On Trip', 'pETA',
#        'aETA', 'Delivered Products', 'Total Products Available', 'ratio'],
#       dtype='object')

# %%
df2.rolling(3).sum()
# Out:
#             Hour  Requests  Completes  Supply Hours  Time On Trip   pETA  \
# Date
# 2013-09-01   NaN       NaN        NaN           NaN           NaN    NaN
# 2013-09-02   NaN       NaN        NaN           NaN           NaN    NaN
# 2013-09-03  33.0     396.0      259.0        137.50         71.55  17.52
# 2013-09-04  33.0     415.0      247.0        124.04         67.67  19.00
# 2013-09-05  33.0     406.0      244.0        118.16         61.23  18.53
# 2013-09-06  33.0     453.0      361.0        139.84         65.66  16.82
# 2013-09-07  33.0     697.0      616.0        185.10         96.71  15.66
# 2013-09-08  33.0     716.0      613.0        191.46         96.91  15.16
# 2013-09-09  33.0     758.0      617.0        191.11        102.38  16.67
# 2013-09-10  33.0     465.0      363.0        148.16         68.73  17.18
# 2013-09-11  33.0     568.0      275.0        109.68         65.33  20.52
# 2013-09-12  33.0     540.0      275.0        115.48         57.73  18.52
# ...

# %%
df2.rolling(3).sum()['Delivered Products'].idxmax()
# Out:
# Timestamp('2013-09-21 00:00:00')

# %%
df2.rolling(3).sum()['Delivered Products']
# Out:
# Date
# 2013-09-01       NaN
# 2013-09-02       NaN
# 2013-09-03     458.0
# 2013-09-04     399.0
# 2013-09-05     423.0
# 2013-09-06     589.0
# 2013-09-07    1073.0
# 2013-09-08    1158.0
# 2013-09-09    1269.0
# 2013-09-10     790.0
# 2013-09-11     543.0
# 2013-09-12     473.0
# 2013-09-13     549.0
# 2013-09-14     669.0
# 2013-09-15     816.0
# 2013-09-16     953.0
# 2013-09-17     732.0
# 2013-09-18     356.0
# 2013-09-19     621.0
# 2013-09-20    1028.0
# 2013-09-21    1702.0
# 2013-09-22    1635.0
# 2013-09-23    1624.0
# 2013-09-24     990.0
# 2013-09-25     568.0
# 2013-09-26     224.0
# 2013-09-27     534.0
# 2013-09-28    1090.0
# 2013-09-29    1568.0
# 2013-09-30    1490.0
# Name: Delivered Products, dtype: float64

# %%
df_last_hour = df[df['Hour'] == 13]
df_last_hour
# Out:
#    Date  Hour  Requests  Completes  Supply Hours  Time On Trip  pETA   aETA  \
# 2   NaT    13        54         50         23.02         17.76  5.07   8.94
# 5   NaT    13       153        107         59.18         23.37  5.14   6.42
# 8   NaT    13        36         15         20.82         12.62  7.82   9.05
# 11  NaT    13        34         20         22.58         17.67  6.51   7.06
# 14  NaT    13       264        109         43.83         29.68  7.27   8.25
# 17  NaT    13       208        101         50.25         30.50  6.81   8.44
# 20  NaT    13       532        340         59.02         39.57  7.83   8.90
# 23  NaT    13       354        100         27.50         19.63  7.36   9.04
# 26  NaT    13       372        120         29.12         23.03  7.06   8.15
# 29  NaT    13        49         12         23.55          9.14  6.46   7.86
# 32  NaT    13       170         50         11.25         10.18  7.47   7.88
# ...

# %%
df_last_hour.columns
# Out:
# Index(['Date', 'Hour', 'Requests', 'Completes', 'Supply Hours', 'Time On Trip',
#        'pETA', 'aETA', 'Delivered Products', 'Total Products Available',
#        'ratio'],
#       dtype='object')

# %%
df_delivered = df_last_hour['Delivered Products']/df_last_hour['Total Products Available']
df_delivered.mean()
# Out:
# 0.7283088992016844

# %%
# df[df['Hour'] == 11]['Delivered Products'].sum()+df[df['Hour'] == 12]+df[df['Hour'] == 13]

# %%
d_11 =df[df['Hour'] == 11]['Delivered Products'].sum()

# %%
d_12 =df[df['Hour'] == 12]['Delivered Products'].sum()

# %%
d_13 =df[df['Hour'] == 13]['Delivered Products'].sum()

# %%
d_13/(d_11+d_12+d_13)*100
# Out:
# 3.3720287451630733

# %%
ord('U')-ord('V')
# Out:
# -1

# %%
ord('B')-ord('A')
# Out:
# 1

# %%
ord('E')-ord('F')
# Out:
# -1

# %%
ord('R')-ord('Q')
# Out:
# 1
