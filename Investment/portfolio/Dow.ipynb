# %%
import pandas as pd
import numpy as np
import re
# !pip install openpyxl

# %%
df_all = pd.read_excel(r"C:\Users\Jinhyun\Documents\GitHub\Python\Investment\portfolio\Dow.xlsx", sheet_name=None, header = 1)

# %%
df_all['Earnings_DOW30_20214Q']
# Out:
#        #   Symbol  Sector  Earnings Date  Prior Y EPS  Prior Q EPS  EPS Est  \
# 0    1.0     AAPL     NaN            NaN          NaN          NaN      NaN
# 1    2.0     AMGN     NaN            NaN          NaN          NaN      NaN
# 2    3.0      AXP     NaN            NaN          NaN          NaN      NaN
# 3    4.0       BA     NaN            NaN          NaN          NaN      NaN
# 4    5.0      CAT     NaN            NaN          NaN          NaN      NaN
# 5    6.0      CRM     NaN            NaN          NaN          NaN      NaN
# 6    7.0     CSCO     NaN            NaN          NaN          NaN      NaN
# 7    8.0      CVX     NaN            NaN          NaN          NaN      NaN
# 8    9.0      DIS     NaN            NaN          NaN          NaN      NaN
# 9   10.0      DOW     NaN            NaN          NaN          NaN      NaN
# 10  11.0       GS     NaN            NaN          NaN          NaN      NaN
# ...

# %%
# !pip install benzinga
# !pip3 install benzinga
from benzinga import financial_data
from benzinga import financial_data
from benzinga import news_data

# %%
from benzinga import financial_data
api_key = "testkey892834789s9s8abshtuy"
bz = financial_data.Benzinga(api_key)
price = bz.delayed_quote(company_tickers = "AAPL") 
print(bz.output(price))
# Out:
# 2022-02-21 14:57.41 [info     ] Status Code: 403 Endpoint: https://api.benzinga.com/api/v1/quoteDelayed?token=testkey892834789s9s8abshtuy&symbols=AAPL
# ---------------------------------------------------------------------------
# TokenAuthenticationError                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8208/114483706.py in <module>
#       2 api_key = "testkey892834789s9s8abshtuy"
#       3 bz = financial_data.Benzinga(api_key)
# ----> 4 price = bz.delayed_quote(company_tickers = "AAPL")
#       5 print(bz.output(price))
#
# ~\Envs\lib\site-packages\benzinga\financial_data.py in delayed_quote(self, company_tickers)
#     124             if self.log:
#     125                 log.info(statement)
# --> 126             self.__check_status(delayed_quote.status_code)
#     127         except requests.exceptions.RequestException as err:
#     128             self.__check_status(err.response.status_code)
#
# ...

# %%
# Out:
# 2022-02-21 14:57.19 [info     ] Status Code: 403 Endpoint: https://api.benzinga.com/api/v1/quoteDelayed?token=testkey892834789s9s8abshtuy&symbols=AAPL
# ---------------------------------------------------------------------------
# TokenAuthenticationError                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8208/3367042524.py in <module>
# ----> 1 price = bz.delayed_quote(company_tickers = "AAPL")
#       2 print(bz.output(price))
#
# ~\Envs\lib\site-packages\benzinga\financial_data.py in delayed_quote(self, company_tickers)
#     124             if self.log:
#     125                 log.info(statement)
# --> 126             self.__check_status(delayed_quote.status_code)
#     127         except requests.exceptions.RequestException as err:
#     128             self.__check_status(err.response.status_code)
#
# ~\Envs\lib\site-packages\benzinga\financial_data.py in __check_status(self, status_code)
#      83             raise TokenAuthenticationError
# ...
