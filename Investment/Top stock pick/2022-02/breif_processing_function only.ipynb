# %%
import pandas as pd
import numpy as np
import re
# !pip install openpyxl

# %%
df_all = pd.read_excel(r"C:\Users\Jinhyun\Documents\GitHub\Python\Investment\Top stock pick\2022-02\Feb stock pick data.xlsx", sheet_name=None, header = 1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19900/271762367.py in <module>
# ----> 1 df_all = pd.read_excel(r"C:\Users\Jinhyun\Documents\GitHub\Python\Investment\Top stock pick\2022-02\Feb stock pick.xlsx", sheet_name=None, header = 1)
#
# ~\Envs\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Envs\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# ~\Envs\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1190             else:
#    1191                 ext = inspect_excel_format(
# -> 1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#    1194                 if ext is None:
#
# ~\Envs\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(content_or_path, storage_options)
#    1069
#    1070     with get_handle(
# -> 1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#    1073         stream = handle.handle
#
# ~\Envs\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Jinhyun\\Documents\\GitHub\\Python\\Investment\\Top stock pick\\2022-02\\Feb stock pick.xlsx'

# %%
def counting_stockpicking(df_all, min_count, save):
    report_lst = list(df_all.keys())
    emp_lst = []

    for report in report_lst:
        check = True
        report_cols = list(df_all[report].columns)
        for col in report_cols:
            if col in ['SYMBOL','Symbol','TICKER', 'Ticker', 'Stock (ticker)', 'Company / Ticker']:
                if '(' in str(list(df_all[report][col])[0]):
                    tmp_lst = list(map(lambda x : re.findall('\(([^)]+)', x), list(df_all[report][col])))
                    emp_lst.append(sum(tmp_lst, []))
                else:
                    emp_lst.append(list(df_all[report][col]))
                check = False

        if check:
            print("*************************************")
            print("Warning!!")
            print("No ticker or symbol")
            print("Need an addittional action")
            print("Report name: ", report)
            print("Report columns: ", df_all[report].columns)
            print("*************************************")
    print('*************************************')
    print('Counted TICKERS')
    result = sum(emp_lst,[])
    count_result =[(i, result.count(i)) for i in result if result.count(i) >= min_count]
    result_rank = pd.DataFrame(sorted(list(set(count_result)), key=lambda x : x[1], reverse = True), columns = ['TICKER','COUNT'])
    print(result)

    if save.upper() == 'YES':
        result_rank.to_excel('result_rank.xlsx')

    return result_rank
counting_stockpicking(df_all, 3,'yes')
# Out:
# *************************************
# Warning!!
# No ticker or symbol
# Need an addittional action
# Report name:  17 small-cap stock ideas have m
# Report columns:  Index([], dtype='object')
# *************************************
# *************************************
# Warning!!
# No ticker or symbol
# Need an addittional action
# Report name:  Morgan Stanley’s quality defens
# Report columns:  Index([], dtype='object')
# *************************************
# *************************************
# Warning!!
# No ticker or symbol
# Need an addittional action
# Report name:  8 stocks, all highly indebted,
# Report columns:  Index(['Stocks', 'Debt/equity ratio', 'EBIT interest coverage ratio',
#        'Number of newsletters recommending'],
#       dtype='object')
# *************************************
# *************************************
# Warning!!
# No ticker or symbol
# Need an addittional action
# Report name:  2022's Dividend Aristocrats Lis
# Report columns:  Index(['Company', 'Sector', 'Years of Dividend Growth',
#        'Dividend Yield (as of Feb. 9)'],
#       dtype='object')
# *************************************
# *************************************
# Warning!!
# No ticker or symbol
# Need an addittional action
# Report name:  Inflation Sensitive Sectors _ S
# Report columns:  Index([], dtype='object')
# *************************************
# *************************************
# Warning!!
# No ticker or symbol
# Need an addittional action
# Report name:  Russell 2000 Stocks with Fast G
# Report columns:  Index([], dtype='object')
# *************************************
# *************************************
# Warning!!
# No ticker or symbol
# Need an addittional action
# Report name:  Barclays Overweight List with l
# Report columns:  Index([], dtype='object')
# *************************************
# *************************************
# Warning!!
# No ticker or symbol
# Need an addittional action
# Report name:  GS Buy-rated Stocks down 70% or
# Report columns:  Index([], dtype='object')
# *************************************
# *************************************
# Warning!!
# No ticker or symbol
# Need an addittional action
# Report name:  UBS Growth Stocks with Upside A
# Report columns:  Index([], dtype='object')
# *************************************
# *************************************
# Warning!!
# No ticker or symbol
# Need an addittional action
# Report name:  the winners and losers as the F
# Report columns:  Index([], dtype='object')
# *************************************
# *************************************
# Warning!!
# No ticker or symbol
# Need an addittional action
# Report name:  Sector Themes in 2022
# Report columns:  Index([], dtype='object')
# *************************************
# *************************************
# Warning!!
# No ticker or symbol
# Need an addittional action
# Report name:  Cheap Russell 1000 stocks based
# Report columns:  Index([], dtype='object')
# *************************************
# *************************************
# Warning!!
# No ticker or symbol
# Need an addittional action
# Report name:  Russell 1000 companies with hig
# Report columns:  Index([], dtype='object')
# *************************************
# *************************************
# Warning!!
# No ticker or symbol
# Need an addittional action
# Report name:  Best Value-Stock Picks
# Report columns:  Index(['Stock', 'P/E ratio (based on trailing 12 months’ earnings)',
#        'Price/book ratio', 'Dividend yield'],
#       dtype='object')
# *************************************
# *************************************
# Counted TICKERS
# ['MRO', 'EOG', 'COP', 'DVN', 'APA', 'ZION', 'BCI', 'PDBC', 'RF', 'CNQ', 'PXD', 'DVN', 'COP', 'CTRA', 'SCHW', 'BAC', 'SI', 'DVN', 'FANG', 'XOM', 'LYFT', 'CAR', 'BA', 'GE', 'BKR', 'COP', 'DIS', 'DVN', 'FANG', 'MCK', 'MU', 'NWSA', 'PSX', 'QCOM', 'SBNY', 'WRK', 'RL', 'MCD', 'STZ', 'EL', 'DXCM', 'VRTX', 'EFX', 'UNP', 'TXN', 'ADBE', 'MRNA', 'CTRA', 'REGN', 'MU', 'QCOM', 'GNTX', 'EA', 'TER', 'GRMN', 'GOOGL', 'HAS', 'MO', 'CLX', 'CVX', 'MMM', 'IBM', 'MRO', 'VLO', 'BKR', 'DVN', 'FCX', 'NUE', 'WYNN', 'CFG', 'SBNY', 'RF', 'MU', 'MISVF', 'FIS', 'GPN', 'AVGO', 'GLW', 'ADI', 'GOOGL', 'TDY', 'PYPL', 'AMGN', 'BX', 'ALLY', 'WHR', 'AEO', 'BLMN', 'CAG', 'DE', 'FCX', 'IBM', 'M', 'MET', 'MCHP', 'NKE', 'TJX', 'ANTM', 'AVGO', 'CI', 'EOG', 'FBHS', 'FCX', 'MU', 'PFE', 'ROST', 'SWKS', 'DD', 'HPQ', 'CHTR', 'NUE', 'COF', 'SYF', 'AZO', 'ORCL', 'BK', 'STX', 'STT', 'AVGO', 'GD', 'BKR', 'EMN', 'DRI', 'RE', 'ABBV', 'FISV', 'MCHP', 'CHTR', 'NWSA', 'TDG', 'NOW', 'QCOM', 'KLAC', 'V', 'EW', 'ALK', 'TMUS', 'GPN', 'FLT', 'BKR', 'C', 'SCHW', 'DE', 'CFG', 'FANG', 'COP', 'EMN', 'NRG', 'FFIV', 'MDLZ', 'ETN', 'XOM', 'CVS', 'WFC', 'BWA', 'WELL', 'DIS', 'SPY', 'ALK', 'MCHP', 'DAL', 'PSX', 'COP', 'MPC', 'QCOM', 'VLO', 'CTLT', 'KLAC', 'HES', 'NUE', 'DHI', 'AMD', 'TXN', 'XLNX', 'URI', 'SCHW', 'ODFL', 'AAPL', 'RL', 'CBOE', 'CCI', 'DOW', 'JNPR', 'JBHT', 'GWW', 'STX', 'PKG', 'AEP', 'PEG', 'D', 'GD', 'KO', 'ABBV', 'PM', 'SRE', 'GLW', 'BRK', 'LNC', 'C', 'VTRS', 'TAP', 'KHC', 'IVZ', 'L', 'AIG', 'CCL', 'FB', 'MA', 'WDAY', 'MRVL', 'TWLO', 'DHI', 'QRVO', 'SPOT', 'TMO', 'LLY', 'TWLO', 'AFRM', 'UAA', 'MU', 'WDC', 'MCHP', 'AMAT', 'ADSK', 'AVGO', 'LRCX', 'EPAM', 'TER', 'FFIV', 'NVDA', 'MPWR', 'SEDG', 'TEL', 'SWK', 'FIS', 'AIZ', 'HAS', 'STT', 'WMT', 'DRI', 'CI', 'HAL', 'SLB', 'OXY', 'COP', 'EOG', 'XOM', 'APA', 'HES', 'MRO', 'ATVI', 'WFC', 'LVS', 'MTB', 'ADM', 'DE', 'CFG', 'DOW', 'VZ', 'IBM', 'CVX', 'WBA', 'MRK', 'AMGN', 'MMM', 'KO', 'INTC', 'BILL', 'CA:DCBO', 'CRWD', 'SMAR', 'LAW', 'SPT', 'U', 'XM', 'DT', 'RNG', 'NOW', 'FIVN', 'AVLR', 'VRNS', 'PANW', 'RPD', 'WDAY', 'PEGA', 'TENB', 'CRNC', 'SAIL', 'DCT', 'MSFT', 'SNPS', 'PVH', 'NKE', 'TPX', 'CL', 'SLB', 'JNJ', 'MMM', 'VRSN', 'WDAY', 'SMG', 'MPC', 'PXD', 'COP', 'GM', 'CAT', 'FDX', 'AAL', 'HON', 'DE', 'GE', 'CL', 'HSY', 'AMT', 'LLY', 'PEP', 'GIS', 'CLX', 'ZS', 'AMGN', 'CMG', 'D', 'ETR', 'EXC', 'AEP', 'PEG', 'MCD', 'CB', 'AIZ', 'WMT', 'ABC', 'TSLA', 'SBUX', 'MRVL', 'CRM', 'DIS', 'MTCH', 'SEDG', 'LYFT', 'RBLX', 'COIN', 'Moderna / MRNA', 'Organon / OGN', 'Viatris / VTRS', 'Lincoln National / LNC', 'Coterra Energy / CTRA', 'Nucor / NUE', 'APA / APA', 'Lennar / LEN', 'PulteGroup / PHM', 'Mosaic / MOS', 'AMAT', 'AVGO', 'KMX', 'DHI', 'HD', 'LRCX', 'LOW', 'MNST', 'PENN', 'PFE', 'VIAC', 'CCL', 'DRI', 'GPS', 'BBWI', 'MGM', 'FANG', 'DFS', 'BA', 'FCX', 'V', 'VRSN', 'NFLX', 'MA', 'FLT', 'MU', 'FB', 'TXN', 'AVGO', 'INTC', 'MSFT', 'ORCL', 'PAYX', 'ADI', 'SWKS', 'JKHY', 'ATVI', 'KLAC', 'FIS', 'MCHP', 'ALK', 'DAL', 'GPN', 'PTC', 'ALGN', 'NWSA', 'FIS', 'MTCH', 'ENPH', 'FDX', 'PYPL', 'HUM', 'SWK', 'BBWI', 'BIO', 'HAS', 'MO', 'CLX', 'CVX', 'MMM', 'IBM', 'CRWD', 'AMZN', 'MRVL', 'WDAY', 'SNPS', 'GOOGL', 'PANW', 'MSFT', 'AIZ', 'CZR', 'CTLT', 'ALK', 'AES', 'IQV', 'LH', 'NWSA', 'SNPS', 'V', 'BBWI', 'TMUS', 'CRM', 'BIO', 'PWR', 'PYPL', 'GM', 'TDY', 'MTCH', 'NKE', 'TSN', 'TGT', 'SWKS', 'MS', 'INTC', 'HPQ', 'DGX', 'DFS', 'ALL', 'AAP', 'NUE', 'STLD', 'MTDR', 'FANG', 'ZIM', 'ESTE', 'CPE', 'AMN', 'CE', 'TX', 'PFE', 'SIMO', 'MU', 'TMUS', 'DISH', 'VIAC', 'DISCA', 'NWSA', 'GM', 'LEN', 'GPS', 'MHK', 'ALK', 'NLSN', 'DXC', 'HD', 'WHR', 'DRI', 'GPC', 'BBY', 'RL', 'YUM', 'SBUX', 'TPR', 'GPS', 'ALGN', 'AMZN', 'FB', 'FISV', 'GOOGL', 'LULU', 'MNST', 'MTCH', 'NFLX', 'PYPL', 'QCOM', 'ROST', 'WDAY', 'EXPE', 'BBY', 'WBA', 'C', 'MET', 'LMT', 'SWK', 'WDC', 'DOW', 'VTR', 'ZION', 'FE', 'DIS', 'SCHW', 'HPE', 'MU', 'VMC', 'FCX', 'FANG', 'DVN', 'F', 'MRO', 'XOM', 'MPC', 'VLO', 'WFC', 'PBCT', 'CFG', 'KEY', 'FITB', 'PNC', 'HPE', 'MOS', 'CMG', 'DHI', 'LOW', 'MCD', 'NKE', 'SYY', 'CAT', 'NSC', 'UNP ...
#    TICKER  COUNT
# 0      MU      8
# 1     COP      7
# 2    FANG      6
# 3    AVGO      6
# 4     DVN      6
# 5    WDAY      5
# 6     DRI      5
# 7    QCOM      5
# 8     ALK      5
# 9    MCHP      5
# 10   NWSA      5
# 11    FCX      5
# 12    DIS      4
# 13   MTCH      4
# 14    DHI      4
# 15   SCHW      4
# 16    BKR      4
# 17    NUE      4
# 18   PYPL      4
# 19  GOOGL      4
# 20    FIS      4
# 21    IBM      4
# 22    MRO      4
# 23    XOM      4
# 24    MMM      4
# 25    NKE      4
# 26    CFG      4
# 27     DE      4
# 28     FB      4
# 29      V      3
# 30   INTC      3
# 31   ATVI      3
# 32   BBWI      3
# 33   AMGN      3
# 34    MPC      3
# 35    GPS      3
# 36    CLX      3
# 37    MCD      3
# 38      C      3
# 39    CVX      3
# 40   MRVL      3
# 41     GM      3
# 42   SWKS      3
# 43   MSFT      3
# 44   TMUS      3
# 45     RL      3
# 46    PFE      3
# 47    DOW      3
# 48    EOG      3
# 49    HAS      3
# 50    VLO      3
# 51   SNPS      3
# 52    GPN      3
# 53    AIZ      3
# 54   KLAC      3
# 55    SWK      3
# 56    TXN      3
# 57    WFC      3

# %%
def Theme_categorizing(df_all, min_count, save):
    report_lst = list(df_all.keys())

    filter_lst = []
    result_dic = {}
    for report in report_lst:
        emp_lst = []
        check = True
        report_cols = list(df_all[report].columns)
        for col in report_cols:
            if col in ['SYMBOL','Symbol','TICKER', 'Ticker', 'Stock (ticker)', 'Company / Ticker']:
                if '(' in str(list(df_all[report][col])[0]):
                    emp_lst.append(sum(list(map(lambda x : re.findall('\(([^)]+)', x), list(df_all[report][col]))),[]))
                else:
                    emp_lst.append(list(df_all[report][col]))
                result_dic[report] = emp_lst
                check = False            
    result = sum(emp_lst,[])
    # print(result)
    # print(result_dic)
    if save.upper() == 'YES':
        pd.DataFrame(result_dic).stack().to_excel(f'Theme_minimum_count_{min_count}.xlsx')
    return pd.DataFrame(result_dic).stack()

# %%
Theme_categorizing(df_all, 0, "Yes")
Theme_categorizing(df_all, 3, "Yes")
Theme_categorizing(df_all, 4, "Yes")
Theme_categorizing(df_all, 5, "Yes")
Theme_categorizing(df_all, 6, "Yes").columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19900/1158136239.py in <module>
# ----> 1 Theme_categorizing(df_all, 0, "Yes")
#       2 Theme_categorizing(df_all, 3, "Yes")
#       3 Theme_categorizing(df_all, 4, "Yes")
#       4 Theme_categorizing(df_all, 5, "Yes")
#       5 Theme_categorizing(df_all, 6, "Yes").columns
#
# NameError: name 'Theme_categorizing' is not defined
